# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
from glob import glob

# %%
## mounting the google drive
from google.colab import drive
drive.mount('/content/gdrive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
data_dir_train = pathlib.Path("/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_dir_test = pathlib.Path('/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Test')

# %%
## getting a count of the images in the training and test sets
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Defining the training dataset using tf.keras.preprocessing.image_dataset_from_directory
## seed=123 
## resizing the images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
 data_dir_train,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Defining the validation dataset using tf.keras.preprocessing.image_dataset_from_directory
## seed=123 
## resizing the images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# Listing out all the classes of skin cancer and storing them in a list. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data

# %%
# creating a code to visualize one instance of all the nine classes present in the dataset
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8")) 
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %%
## keeping the datasset in the memory
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Model Creation
# #### Creating a CNN model, which can accurately detect 9 classes present in the dataset. Using ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Creating the base CNN model
num_classes = 9

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255,offset=0, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# ### Model Compilation

# %%
### choosing an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 180, 180, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 90, 90, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 90, 90, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 45, 45, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 30976)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               3965056
# _________________________________________________________________
# dense_1 (Dense)              (None, 9)                 1161
# =================================================================
# Total params: 3,989,801
# Trainable params: 3,989,801
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Model Training

# %%
## training the model for 20 epochs
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 370s 1s/step - loss: 2.0172 - accuracy: 0.2567 - val_loss: 1.8506 - val_accuracy: 0.2953
# Epoch 2/20
# 56/56 [==============================] - 2s 43ms/step - loss: 1.6945 - accuracy: 0.3783 - val_loss: 1.5788 - val_accuracy: 0.4027
# Epoch 3/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.5323 - accuracy: 0.4598 - val_loss: 1.5203 - val_accuracy: 0.5190
# Epoch 4/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.3935 - accuracy: 0.5179 - val_loss: 1.4384 - val_accuracy: 0.4855
# Epoch 5/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.3152 - accuracy: 0.5352 - val_loss: 1.3345 - val_accuracy: 0.5481
# Epoch 6/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.2272 - accuracy: 0.5664 - val_loss: 1.3532 - val_accuracy: 0.5548
# Epoch 7/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.1361 - accuracy: 0.6016 - val_loss: 1.4991 - val_accuracy: 0.5168
# Epoch 8/20
# 56/56 [==============================] - 2s 40ms/step - loss: 1.0256 - accuracy: 0.6390 - val_loss: 1.4301 - val_accuracy: 0.5056
# Epoch 9/20
# 56/56 [==============================] - 2s 40ms/step - loss: 1.0133 - accuracy: 0.6323 - val_loss: 1.4990 - val_accuracy: 0.5570
# Epoch 10/20
# 56/56 [==============================] - 2s 40ms/step - loss: 0.9126 - accuracy: 0.6674 - val_loss: 1.4734 - val_accuracy: 0.5414
# Epoch 11/20
# 56/56 [==============================] - 2s 41ms/step - loss: 0.8515 - accuracy: 0.6858 - val_loss: 1.6191 - val_accuracy: 0.5526
# Epoch 12/20
# 56/56 [==============================] - 2s 41ms/step - loss: 0.7653 - accuracy: 0.7221 - val_loss: 1.5201 - val_accuracy: 0.5235
# Epoch 13/20
# 56/56 [==============================] - 2s 40ms/step - loss: 0.7369 - accuracy: 0.7360 - val_loss: 1.7284 - val_accuracy: 0.5414
# Epoch 14/20
# 56/56 [==============================] - 2s 41ms/step - loss: 0.6331 - accuracy: 0.7706 - val_loss: 1.9298 - val_accuracy: 0.5615
# Epoch 15/20
# 56/56 [==============================] - 2s 41ms/step - loss: 0.6102 - accuracy: 0.7846 - val_loss: 2.0216 - val_accuracy: 0.5011
# Epoch 16/20
# 56/56 [==============================] - 2s 40ms/step - loss: 0.5595 - accuracy: 0.7946 - val_loss: 1.7409 - val_accuracy: 0.5660
# Epoch 17/20
# 56/56 [==============================] - 2s 41ms/step - loss: 0.4692 - accuracy: 0.8248 - val_loss: 1.9923 - val_accuracy: 0.5436
# Epoch 18/20
# 56/56 [==============================] - 2s 41ms/step - loss: 0.4437 - accuracy: 0.8443 - val_loss: 1.9907 - val_accuracy: 0.5369
# Epoch 19/20
# 56/56 [==============================] - 2s 41ms/step - loss: 0.4243 - accuracy: 0.8354 - val_loss: 2.0474 - val_accuracy: 0.5481
# Epoch 20/20
# 56/56 [==============================] - 2s 41ms/step - loss: 0.3399 - accuracy: 0.8666 - val_loss: 2.2413 - val_accuracy: 0.5145

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ### Findings from above figures
# - There is a huge mismatch between the training and the validation accuracy.
# - The plots above also show an almost linear trend in the training accuracy with epochs but the validation accuracy is fluctuating around the 50% mark.
# - These obsservations clearly indicate towards overfitting!

# %%
# choosing an appropriate data augumentation strategy 
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(img_height, 
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

# %%
# visualizing how the augmentation strategy works for one instance of training image.
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# ### Create the model, compile and train the model

# %%
## using dropout layer
data_augmentation = tf.keras.Sequential([
  layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
  layers.experimental.preprocessing.RandomRotation(0.2),
])
model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# ### Compiling the model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
## training the model for 20 epochs
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 4s 51ms/step - loss: 2.1241 - accuracy: 0.2506 - val_loss: 1.8636 - val_accuracy: 0.3199
# Epoch 2/20
# 56/56 [==============================] - 3s 46ms/step - loss: 1.7998 - accuracy: 0.3454 - val_loss: 1.6762 - val_accuracy: 0.4116
# Epoch 3/20
# 56/56 [==============================] - 3s 46ms/step - loss: 1.6166 - accuracy: 0.4291 - val_loss: 1.4765 - val_accuracy: 0.4787
# Epoch 4/20
# 56/56 [==============================] - 3s 47ms/step - loss: 1.4825 - accuracy: 0.4766 - val_loss: 1.5338 - val_accuracy: 0.4541
# Epoch 5/20
# 56/56 [==============================] - 3s 46ms/step - loss: 1.4750 - accuracy: 0.4860 - val_loss: 1.4881 - val_accuracy: 0.4877
# Epoch 6/20
# 56/56 [==============================] - 3s 46ms/step - loss: 1.3741 - accuracy: 0.5140 - val_loss: 1.4141 - val_accuracy: 0.5123
# Epoch 7/20
# 56/56 [==============================] - 3s 46ms/step - loss: 1.4383 - accuracy: 0.4989 - val_loss: 1.4934 - val_accuracy: 0.4586
# Epoch 8/20
# 56/56 [==============================] - 3s 46ms/step - loss: 1.3655 - accuracy: 0.5179 - val_loss: 1.3652 - val_accuracy: 0.5235
# Epoch 9/20
# 56/56 [==============================] - 3s 47ms/step - loss: 1.3498 - accuracy: 0.5307 - val_loss: 1.3906 - val_accuracy: 0.5101
# Epoch 10/20
# 56/56 [==============================] - 3s 46ms/step - loss: 1.3283 - accuracy: 0.5229 - val_loss: 1.3994 - val_accuracy: 0.5123
# Epoch 11/20
# 56/56 [==============================] - 3s 46ms/step - loss: 1.2610 - accuracy: 0.5385 - val_loss: 1.3585 - val_accuracy: 0.5436
# Epoch 12/20
# 56/56 [==============================] - 3s 46ms/step - loss: 1.2710 - accuracy: 0.5458 - val_loss: 1.3813 - val_accuracy: 0.5056
# Epoch 13/20
# 56/56 [==============================] - 3s 47ms/step - loss: 1.2749 - accuracy: 0.5396 - val_loss: 1.3647 - val_accuracy: 0.5436
# Epoch 14/20
# 56/56 [==============================] - 3s 46ms/step - loss: 1.2311 - accuracy: 0.5592 - val_loss: 1.3590 - val_accuracy: 0.5414
# Epoch 15/20
# 56/56 [==============================] - 3s 46ms/step - loss: 1.2449 - accuracy: 0.5547 - val_loss: 1.3992 - val_accuracy: 0.5168
# Epoch 16/20
# 56/56 [==============================] - 3s 46ms/step - loss: 1.2376 - accuracy: 0.5441 - val_loss: 1.2963 - val_accuracy: 0.5481
# Epoch 17/20
# 56/56 [==============================] - 3s 46ms/step - loss: 1.2217 - accuracy: 0.5636 - val_loss: 1.3587 - val_accuracy: 0.5280
# Epoch 18/20
# 56/56 [==============================] - 3s 48ms/step - loss: 1.1801 - accuracy: 0.5675 - val_loss: 1.4046 - val_accuracy: 0.5481
# Epoch 19/20
# 56/56 [==============================] - 3s 46ms/step - loss: 1.2060 - accuracy: 0.5552 - val_loss: 1.4188 - val_accuracy: 0.4899
# Epoch 20/20
# 56/56 [==============================] - 3s 46ms/step - loss: 1.1850 - accuracy: 0.5692 - val_loss: 1.3636 - val_accuracy: 0.5593

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Findings:
# - The training and the validation accuracies are close to each other.
# - The graph above also shows a close correspondence between the training and the validation accuracies.
# - The problem of overfitting has been solved but both the accuracies are now in the lower ranges.
# - There could be class imbalances which are hampering the model performance.

# %% [markdown]
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.

# %% [markdown]
# ### Creating orignal_df to visualize the class imbalance

# %%
## defining a path dictionary
path_dict = {os.path.splitext(os.path.basename(x))[0]: x
                     for x in glob(os.path.join(data_dir_train, '*', '*.jpg'))}

# %%
## checking out how the paths look
print(path_dict)
# Out:
# {'ISIC_0026626': '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/ISIC_0026626.jpg', 'ISIC_0027668': '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/ISIC_0027668.jpg', 'ISIC_0028941': '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/ISIC_0028941.jpg', 'ISIC_0029900': '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029900.jpg', 'ISIC_0027254': '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/ISIC_0027254.jpg', 'ISIC_0030142': '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0030142.jpg', 'ISIC_0027896': '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/ISIC_0027896.jpg', 'ISIC_0027452': '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/ISIC_0027452.jpg', 'ISIC_0029210': '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/ISIC_0029210.jpg', 'ISIC_0026905': '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/ISIC_0026905.jpg', 'ISIC_0028990': '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/ISIC_0028990.jpg', 'ISIC_0026040': '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/ISIC_0026040.jpg', 'ISIC_0030408': '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0030408.jpg', 'ISIC_0026709': '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/ISIC_0026709.jpg', 'ISIC_0030143': '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0030143.jpg', 'ISIC_0029025': '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/ISIC_0029025.jpg', 'ISIC_0027562': '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/ISIC_0027562.jpg', 'ISIC_0026468': '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/ISIC_0026468.jpg', 'ISIC_0026984': '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/ISIC_0026984.jpg', 'ISIC_0028558': '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/ISIC_0028558.jpg', 'ISIC_0026702': '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/ISIC_0026702.jpg', 'ISIC_0027650': '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/ISIC_0027650.jpg', 'ISIC_0025992': '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/ISIC_0025992.jpg', 'ISIC_0026625': '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/ISIC_0026625.jpg', 'ISIC_0026171': '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/ISIC_0026171.jpg', 'ISIC_0029133': '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/ISIC_0029133.jpg', 'ISIC_0028076': '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/ISIC_0028076.jpg', 'ISIC_002 ...

# %%
## creating a list from the dictionary
a = list(path_dict.items())

# %%
## defining the path_list
path_list = list(map(lambda x: x[1], a))

# %%
## defining the labels list
labels_list = [i.split('/')[-2] for i in path_list]

# %%
## creating the orignal_df
orignal_df = pd.DataFrame(list(dict(zip(path_list, labels_list)).items()),columns = ['Path','Label'])
orignal_df.head()
# Out:
#                                                 Path              Label
# 0  /content/gdrive/MyDrive/Drive Files/Skin cance...              nevus
# 1  /content/gdrive/MyDrive/Drive Files/Skin cance...              nevus
# 2  /content/gdrive/MyDrive/Drive Files/Skin cance...              nevus
# 3  /content/gdrive/MyDrive/Drive Files/Skin cance...  actinic keratosis
# 4  /content/gdrive/MyDrive/Drive Files/Skin cance...              nevus

# %%
## checking the value couhts of the different labels
orignal_df['Label'].value_counts()
# Out:
# pigmented benign keratosis    462
# melanoma                      438
# basal cell carcinoma          376
# nevus                         357
# squamous cell carcinoma       181
# vascular lesion               139
# dermatofibroma                 95
# actinic keratosis              52
# seborrheic keratosis            2
# Name: Label, dtype: int64

# %%
## visualizing the value counts
orignal_df['Label'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# #### - Which class has the least number of samples?
#          - "seborrheic keratosis"
# #### - Which classes dominate the data in terms proportionate number of samples?
#           - "pigmented benign keratosis'

# %% [markdown]
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
## installing Augmentor
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.8-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.1.2)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.19.5)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.41.1)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.8

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
## pipeline for actinic keratosis
import Augmentor
p = Augmentor.Pipeline('/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis')
p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
p.sample(500)
# Out:
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F15059DFAD0>:   0%|          | 1/500 [00:00<00:55,  8.97 Samples/s]
# Initialised with 114 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F15059FA690>: 100%|██████████| 500/500 [00:22<00:00, 22.70 Samples/s]

# %%
## pipeline for basal cell carcinoma
p = Augmentor.Pipeline('/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma')
p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
p.sample(500)
# Out:
# Executing Pipeline:   0%|          | 0/500 [00:00<?, ? Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F1506CA4DD0>: 100%|██████████| 500/500 [00:22<00:00, 22.37 Samples/s]

# %%
## pipeline for dermatofibroma
p = Augmentor.Pipeline('/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma')
p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
p.sample(500)
# Out:
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F15059FA8D0>:   0%|          | 1/500 [00:00<01:26,  5.75 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F1506CA4F50>: 100%|██████████| 500/500 [00:22<00:00, 22.56 Samples/s]

# %%
## pipeline for melanoma
p = Augmentor.Pipeline('/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma')
p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
p.sample(500)
# Out:
# Executing Pipeline:   0%|          | 0/500 [00:00<?, ? Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x7F1501E00B90>: 100%|██████████| 500/500 [01:36<00:00,  5.20 Samples/s]

# %%
## pipeline for nevus
p = Augmentor.Pipeline('/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus')
p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
p.sample(500)
# Out:
# Executing Pipeline:   0%|          | 0/500 [00:00<?, ? Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=3072x2304 at 0x7F15027A1150>: 100%|██████████| 500/500 [01:36<00:00,  5.17 Samples/s]

# %%
## pipeline for pigmented benign keratosis
p = Augmentor.Pipeline('/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis')
p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
p.sample(500)
# Out:
# Executing Pipeline:   0%|          | 0/500 [00:00<?, ? Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F1501E5B510>: 100%|██████████| 500/500 [00:22<00:00, 21.92 Samples/s]

# %%
## pipeline for seborrheic keratosis
p = Augmentor.Pipeline('/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis')
p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
p.sample(500)
# Out:
# Executing Pipeline:   0%|          | 0/500 [00:00<?, ? Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F1501F5F250>: 100%|██████████| 500/500 [00:49<00:00, 10.17 Samples/s]

# %%
## pipeline for squamous cell carcinoma
p = Augmentor.Pipeline('/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma')
p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
p.sample(500)
# Out:
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F1501E8E150>:   0%|          | 1/500 [00:00<01:02,  7.96 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F1506C9FBD0>: 100%|██████████| 500/500 [00:22<00:00, 22.02 Samples/s]

# %%
## pipeline for vascular lesion
p = Augmentor.Pipeline('/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular les
jpg',
#  '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0010942.jpg_dceb646d-3fb1-41d2-adab-6ac166cbafee.jpg',
#  '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0010898.jpg_ad5b5361-0836-4e5e-9ccb-54eba9a888be.jpg',
#  '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0011118.jpg_9be38a87-1a43-41b7-bb2e-b87cca46429e.jpg',
#  '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0011138.jpg_d80ff3e0-8f0d-481d-a36a-82f18d0f3b80.jpg',
#  '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0011012.jpg_6765bb2b-f65a-46b3-b5ba-fb33ce759356.jpg',
#  '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0011094.jpg_4235a190-2464-457d-a9e3-a303bf9b4ff1.jpg',
#  '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0010862.jpg_f091ee11-01b6-442a-ac66-680e7a517f06.jpg',
#  '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0010876.jpg_1964e618-8ff8-49ea-8412-9fc93e48cc44.jpg',
#  '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0010862.jpg_833f22f1-9e74-4814-bd06-f9327c14906d.jpg',
#  '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0011181.jpg_123f3381-760e-40f8-ad9e-e8f0823c4c39.jpg',
#  '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0011112.jpg_6f1b124a-cc52-4f8f-b759-7ff049955fd6.jpg',
#  '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0011112.jpg_d12d5bdb-be1c-4621-88c2-33f165a01f4f.jpg',
#  '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0010995.jpg_5f43d173-e3ef-4463-af26-3ffc74e326d2.jpg',
#  '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0011166.jpg_fe4af02d-10b7-443a-8d87-4e34444192cd.jpg',
#  '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0011013.jpg_699d4cd1-7152-48d6-b63e-5c82a769d287.jpg',
#  '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0010995.jpg_783429bc-a46f-44e1-9df9-d81f5d4676dc.jpg',
#  '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0011007.jpg_1c493d75-37fa-4ca5-bdc8-96271a2a4c07.jpg',
#  '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0010990.jpg_846b804f-b6d6-4ecb-888f-97272a8b5cc5.jpg',
#  '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0010863.jpg_59677ddb-a207-4071-b817-2bb0b15b393f.jpg',
#  '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0010860.jpg_01ce96ef-be93-4ff0-adda-d2fd1f2ee068.jpg',
#  '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0010876.jpg_4a04f995-4f88-47b7-871d-d0ad7324969f.jpg',
#  '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0010965.jpg_0755f5ad-14b0-45a8-8b9c-34888bd98a6d.jpg',
#  '/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0011176.jpg_ef8b1cae-9e2b-4a83-b9b4-02a7f3650d29.jpg',
#  ...]

# %%
## Creating the new lesion list
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new
# Out:
# ['actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  ...]

# %%
## creating a dictionary by zipping the two lists
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
## creating new_df
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = orignal_df.append(df2)

# %%
## checking the value counts in the new_df
new_df['Label'].value_counts()
# Out:
# pigmented benign keratosis    962
# melanoma                      938
# basal cell carcinoma          876
# nevus                         857
# squamous cell carcinoma       681
# vascular lesion               639
# dermatofibroma                595
# actinic keratosis             552
# seborrheic keratosis          502
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### Train the model on the data created using Augmentor

# %%
## defing the parameters
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# ####Create a training dataset

# %%
## remounting the drive
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
## Defining the training dataset using tf.keras.preprocessing.image_dataset_from_directory
## seed=123 
## resizing the images to the size img_height*img_width, while writting the dataset
data_dir_train="/content/gdrive/MyDrive/Drive Files/Skin cancer ISIC The International Skin Imaging Collaboration/Train"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',## Todo choose the correct parameter value, so that only training data is refered to,,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# #### Create a validation dataset

# %%
## Defining the validation dataset using tf.keras.preprocessing.image_dataset_from_directory
## seed=123 
## resizing the images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset ='validation', ## Todo choose the correct parameter value, so that only validation data is refered to,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# #### Create your model (make sure to include normalization)

# %%
num_classes = 9

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255,offset=0, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.BatchNormalization(),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.BatchNormalization(),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# #### Compile your model (Choose optimizer and loss function appropriately)

# %%
## compiling the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ####  Train your model

# %%
## training for 30 epochs
epochs = 30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 169/169 [==============================] - 46s 264ms/step - loss: 2.4607 - accuracy: 0.2583 - val_loss: 2.1597 - val_accuracy: 0.1166
# Epoch 2/30
# 169/169 [==============================] - 44s 253ms/step - loss: 1.5238 - accuracy: 0.4238 - val_loss: 2.1961 - val_accuracy: 0.2717
# Epoch 3/30
# 169/169 [==============================] - 44s 252ms/step - loss: 1.3398 - accuracy: 0.4781 - val_loss: 1.5199 - val_accuracy: 0.4581
# Epoch 4/30
# 169/169 [==============================] - 43s 250ms/step - loss: 1.2025 - accuracy: 0.5395 - val_loss: 1.3805 - val_accuracy: 0.5063
# Epoch 5/30
# 169/169 [==============================] - 44s 254ms/step - loss: 1.0515 - accuracy: 0.5885 - val_loss: 1.7973 - val_accuracy: 0.4588
# Epoch 6/30
# 169/169 [==============================] - 44s 253ms/step - loss: 0.9499 - accuracy: 0.6274 - val_loss: 1.1662 - val_accuracy: 0.5865
# Epoch 7/30
# 169/169 [==============================] - 45s 258ms/step - loss: 0.8442 - accuracy: 0.6734 - val_loss: 1.3388 - val_accuracy: 0.5360
# Epoch 8/30
# 169/169 [==============================] - 45s 259ms/step - loss: 0.7491 - accuracy: 0.7177 - val_loss: 1.3520 - val_accuracy: 0.5969
# Epoch 9/30
# 169/169 [==============================] - 43s 249ms/step - loss: 0.6346 - accuracy: 0.7667 - val_loss: 1.0458 - val_accuracy: 0.6548
# Epoch 10/30
# 169/169 [==============================] - 42s 243ms/step - loss: 0.5319 - accuracy: 0.8006 - val_loss: 0.9765 - val_accuracy: 0.6837
# Epoch 11/30
# 169/169 [==============================] - 43s 249ms/step - loss: 0.4794 - accuracy: 0.8203 - val_loss: 1.3207 - val_accuracy: 0.6437
# Epoch 12/30
# 169/169 [==============================] - 44s 251ms/step - loss: 0.4060 - accuracy: 0.8505 - val_loss: 0.9236 - val_accuracy: 0.7216
# Epoch 13/30
# 169/169 [==============================] - 43s 248ms/step - loss: 0.3291 - accuracy: 0.8772 - val_loss: 1.3252 - val_accuracy: 0.6214
# Epoch 14/30
# 169/169 [==============================] - 43s 248ms/step - loss: 0.3320 - accuracy: 0.8770 - val_loss: 0.9674 - val_accuracy: 0.7350
# Epoch 15/30
# 169/169 [==============================] - 44s 252ms/step - loss: 0.3118 - accuracy: 0.8863 - val_loss: 0.8578 - val_accuracy: 0.7610
# Epoch 16/30
# 169/169 [==============================] - 44s 253ms/step - loss: 0.2642 - accuracy: 0.9036 - val_loss: 0.9487 - val_accuracy: 0.7142
# Epoch 17/30
# 169/169 [==============================] - 44s 253ms/step - loss: 0.2522 - accuracy: 0.9030 - val_loss: 1.4035 - val_accuracy: 0.6607
# Epoch 18/30
# 169/169 [==============================] - 43s 250ms/step - loss: 0.2510 - accuracy: 0.9086 - val_loss: 1.4016 - val_accuracy: 0.6377
# Epoch 19/30
# 169/169 [==============================] - 43s 247ms/step - loss: 0.2381 - accuracy: 0.9091 - val_loss: 4.2655 - val_accuracy: 0.3935
# Epoch 20/30
# 169/169 [==============================] - 43s 250ms/step - loss: 0.2156 - accuracy: 0.9173 - val_loss: 0.8784 - val_accuracy: 0.7847
# Epoch 21/30
# 169/169 [==============================] - 43s 246ms/step - loss: 0.2056 - accuracy: 0.9247 - val_loss: 1.2653 - val_accuracy: 0.7268
# Epoch 22/30
# 169/169 [==============================] - 43s 249ms/step - loss: 0.1837 - accuracy: 0.9297 - val_loss: 1.0035 - val_accuracy: 0.7372
# Epoch 23/30
# 169/169 [==============================] - 43s 246ms/step - loss: 0.1660 - accuracy: 0.9369 - val_loss: 0.8447 - val_accuracy: 0.8033
# Epoch 24/30
# 169/169 [==============================] - 43s 250ms/step - loss: 0.1791 - accuracy: 0.9332 - val_loss: 1.1431 - val_accuracy: 0.7194
# Epoch 25/30
# 169/169 [==============================] - 43s 248ms/step - loss: 0.1940 - accuracy: 0.9288 - val_loss: 1.8797 - val_accuracy: 0.6600
# Epoch 26/30
# 169/169 [==============================] - 43s 248ms/step - loss: 0.1830 - accuracy: 0.9312 - val_loss: 1.2025 - val_accuracy: 0.7305
# Epoch 27/30
# 169/169 [==============================] - 43s 249ms/step - loss: 0.1568 - accuracy: 0.9390 - val_loss: 1.8868 - val_accuracy: 0.6236
# Epoch 28/30
# 169/169 [==============================] - 43s 249ms/step - loss: 0.1693 - accuracy: 0.9355 - val_loss: 1.0094 - val_accuracy: 0.7914
# Epoch 29/30
# 169/169 [==============================] - 42s 244ms/step - loss: 0.1652 - accuracy: 0.9375 - val_loss: 0.9278 - val_accuracy: 0.7803
# Epoch 30/30
# 169/169 [==============================] - 43s 246ms/step - loss: 0.1491 - accuracy: 0.9420 - val_loss: 1.6113 - val_accuracy: 0.6941

# %% [markdown]
# ####  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?
# - The results indicate some overfitting tendency in the model still exists.
# - The class rebalance did help though, in reducing the gap between the training and the validation datasets. This gap was earlier in the range of about 40% and now it has come down to about 20% after class rebalance.
# - Given the limited resoures in terms of computing horsepower and time, this model is somewhat satisfactory.
